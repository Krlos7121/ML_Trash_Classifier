# %% [markdown]
# # Modelo de Clasificación de Imágenes de Basura
#
# Carlos Iván Fonseca Mondragón | A01771689

# %%
# Importación de librerías
import joblib
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D)
from tensorflow.keras.regularizers import l2 as kernel_regularizer_l2

# %%
# Verificar si TensorFlow detecta la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    print("GPU detectada:", physical_devices)
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
else:
    print("No se detectó GPU. Usando CPU.")
# Out:
# GPU detectada: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Cargar datasets preprocesados

# %%
# Cargar metadatos
metadata = joblib.load("processed_datasets/metadata.pkl")

class_names = metadata["class_names"]
class_weights = metadata["class_weights"]
image_size = tuple(metadata["image_size"])
batch_size = metadata["batch_size"]
num_classes = metadata["num_classes"]

print("Metadatos cargados:")
print(f"  Clases: {class_names}")
print(f"  Pesos de clase: {class_weights}")
print(f"  Número de clases: {num_classes}")
print(f"  Tamaño de imagen: {image_size}")
print(f"  Tamaño de batch: {batch_size}")
# Out:
# Metadatos cargados:
#   Clases: ['Cardboard', 'Food Organics', 'Glass', 'Metal', 'Miscellaneous Trash', 'Paper', 'Plastic', 'Textile Trash', 'Vegetation']
#   Pesos de clase: {0: 1.0876190476190477, 1: 1.2903954802259887, 2: 1.2440087145969498, 3: 0.6737463126843658, 4: 1.084520417853751, 5: 1.054478301015697, 6: 0.5758951084215834, 7: 1.655072463768116, 8: 1.239956568946797}
#   Número de clases: 9
#   Tamaño de imagen: (224, 224)
#   Tamaño de batch: 32

# %%
# Cargar datasets preprocesados

train_dataset_raw = tf.data.Dataset.load("processed_datasets/train")
normalized_validation_dataset = tf.data.Dataset.load("processed_datasets/validation")
normalized_test_dataset = tf.data.Dataset.load("processed_datasets/test")

print(f"Train dataset: {len(train_dataset_raw)} batches")
print(f"Validation dataset: {len(normalized_validation_dataset)} batches")
print(f"Test dataset: {len(normalized_test_dataset)} batches")
# Out:
# Train dataset: 108 batches
# Validation dataset: 12 batches
# Test dataset: 30 batches
# 2026-06-06 14:06:33.403593: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2026-06-06 14:06:33.403614: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2026-06-06 14:06:33.403623: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 25.92 GB
# 2026-06-06 14:06:33.403639: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-06-06 14:06:33.403649: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Data Augmentation

# %%
# Definir capas de augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.15),
    tf.keras.layers.RandomZoom(0.15),
    tf.keras.layers.RandomContrast(0.1),
])

def augment_images(x, y):
    return data_augmentation(x, training=True), y

# Aplicar augmentation al dataset de entrenamiento
augmented_train_dataset = (
    train_dataset_raw
    .map(augment_images, num_parallel_calls=tf.data.AUTOTUNE)
    .shuffle(1000)
    .prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# ## Definición del modelo

# %%
# Arquitectura del modelo de 5 capas convolucionales
model = tf.keras.Sequential([
    Input(shape=(224, 224, 3)),
    
    Conv2D(32, (3,3), activation='relu', padding='same', kernel_regularizer=kernel_regularizer_l2(1e-4)),
    BatchNormalization(),
    MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu', padding='same', kernel_regularizer=kernel_regularizer_l2(1e-4)),
    BatchNormalization(),
    MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu', padding='same', kernel_regularizer=kernel_regularizer_l2(1e-4)),
    BatchNormalization(),
    MaxPooling2D((2,2)),

    Conv2D(256, (3,3), activation='relu', padding='same', kernel_regularizer=kernel_regularizer_l2(1e-4)),
    BatchNormalization(),
    MaxPooling2D((2,2)),

    Conv2D(512, (3,3), activation='relu', padding='same', kernel_regularizer=kernel_regularizer_l2(1e-4)),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Conv2D(1024, (3,3), activation='relu', padding='same', kernel_regularizer=kernel_regularizer_l2(1e-4)),
    BatchNormalization(),
    MaxPooling2D((2,2)),

    GlobalAveragePooling2D(),

    Dense(256, activation='relu', kernel_regularizer=kernel_regularizer_l2(1e-4)),
    Dropout(0.6),

    Dense(num_classes, activation='softmax')
])

# %%
# Compilar modelo
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

print("\nResumen del modelo:")
model.summary()
# Out:
# Resumen del modelo:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 7, 7, 1024)     │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 3, 3, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         2,313 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,560,969 (25.03 MB)
#  Trainable params: 6,556,937 (25.01 MB)
#  Non-trainable params: 4,032 (15.75 KB)

# %% [markdown]
# ## Entrenamiento

# %%
# Configurar callbacks
EPOCHS = 50

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_model_experimental.keras", 
        save_best_only=True, 
        monitor='val_accuracy',
        mode="max"
    ),
    
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_accuracy', 
        factor=0.5, 
        patience=15, 
        min_lr=1e-7,
        mode="max",
    ),
    
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', 
        patience=30, 
        restore_best_weights=True,
        mode="max",

    )
]

# %%
# Entrenar el modelo
history = model.fit(
    augmented_train_dataset,
    validation_data=normalized_validation_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
    # class_weight=class_weights (deprecado en el modelo actual, pues genera mucha variación en el accuracy, pero se mantiene por si puede ser de utilidad al implementar una mejora)
)
# Out:
# Epoch 1/50
# 2026-06-06 14:06:34.811851: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.3640 - loss: 3.4233 - val_accuracy: 0.0789 - val_loss: 3.4945 - learning_rate: 1.0000e-04
# Epoch 2/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 133ms/step - accuracy: 0.4224 - loss: 2.8793 - val_accuracy: 0.0789 - val_loss: 6.9614 - learning_rate: 1.0000e-04
# Epoch 3/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - accuracy: 0.4492 - loss: 2.8471 - val_accuracy: 0.0816 - val_loss: 8.0380 - learning_rate: 1.0000e-04
# Epoch 4/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 139ms/step - accuracy: 0.4673 - loss: 2.8691 - val_accuracy: 0.2658 - val_loss: 4.4586 - learning_rate: 1.0000e-04
# Epoch 5/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 138ms/step - accuracy: 0.4819 - loss: 2.8279 - val_accuracy: 0.4474 - val_loss: 2.8451 - learning_rate: 1.0000e-04
# Epoch 6/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 137ms/step - accuracy: 0.4939 - loss: 2.7993 - val_accuracy: 0.4816 - val_loss: 2.8873 - learning_rate: 1.0000e-04
# Epoch 7/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 137ms/step - accuracy: 0.5123 - loss: 2.7461 - val_accuracy: 0.4816 - val_loss: 2.9045 - learning_rate: 1.0000e-04
# Epoch 8/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 137ms/step - accuracy: 0.5304 - loss: 2.7027 - val_accuracy: 0.4763 - val_loss: 4.1907 - learning_rate: 1.0000e-04
# Epoch 9/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 137ms/step - accuracy: 0.5458 - loss: 2.6744 - val_accuracy: 0.5763 - val_loss: 2.1773 - learning_rate: 1.0000e-04
# Epoch 10/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.5569 - loss: 2.6073 - val_accuracy: 0.5184 - val_loss: 3.2922 - learning_rate: 1.0000e-04
# Epoch 11/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.5595 - loss: 2.5548 - val_accuracy: 0.5316 - val_loss: 3.4325 - learning_rate: 1.0000e-04
# Epoch 12/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.5633 - loss: 2.5931 - val_accuracy: 0.4289 - val_loss: 4.3278 - learning_rate: 1.0000e-04
# Epoch 13/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.5779 - loss: 2.4854 - val_accuracy: 0.3947 - val_loss: 4.7973 - learning_rate: 1.0000e-04
# Epoch 14/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - accuracy: 0.6074 - loss: 2.3498 - val_accuracy: 0.5053 - val_loss: 3.9356 - learning_rate: 1.0000e-04
# Epoch 15/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.5966 - loss: 2.4937 - val_accuracy: 0.5447 - val_loss: 3.1686 - learning_rate: 1.0000e-04
# Epoch 16/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.6115 - loss: 2.3534 - val_accuracy: 0.5658 - val_loss: 3.2747 - learning_rate: 1.0000e-04
# Epoch 17/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.6185 - loss: 2.2001 - val_accuracy: 0.4368 - val_loss: 3.9781 - learning_rate: 1.0000e-04
# Epoch 18/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.6427 - loss: 2.1309 - val_accuracy: 0.3658 - val_loss: 5.3350 - learning_rate: 1.0000e-04
# Epoch 19/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 133ms/step - accuracy: 0.6378 - loss: 2.1589 - val_accuracy: 0.5737 - val_loss: 2.8828 - learning_rate: 1.0000e-04
# Epoch 20/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - accuracy: 0.6468 - loss: 2.1431 - val_accuracy: 0.5211 - val_loss: 3.6218 - learning_rate: 1.0000e-04
# Epoch 21/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 132ms/step - accuracy: 0.6687 - loss: 1.9576 - val_accuracy: 0.3684 - val_loss: 6.0581 - learning_rate: 1.0000e-04
# Epoch 22/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 132ms/step - accuracy: 0.6626 - loss: 1.9751 - val_accuracy: 0.5500 - val_loss: 3.0727 - learning_rate: 1.0000e-04
# Epoch 23/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 132ms/step - accuracy: 0.6877 - loss: 1.8996 - val_accuracy: 0.5263 - val_loss: 3.5938 - learning_rate: 1.0000e-04
# Epoch 24/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 132ms/step - accuracy: 0.6874 - loss: 1.8434 - val_accuracy: 0.5474 - val_loss: 2.9951 - learning_rate: 1.0000e-04
# Epoch 25/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.7125 - loss: 1.6712 - val_accuracy: 0.5947 - val_loss: 2.3994 - learning_rate: 5.0000e-05
# Epoch 26/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 132ms/step - accuracy: 0.7250 - loss: 1.5832 - val_accuracy: 0.5947 - val_loss: 3.0910 - learning_rate: 5.0000e-05
# Epoch 27/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 133ms/step - accuracy: 0.7513 - loss: 1.4324 - val_accuracy: 0.6105 - val_loss: 2.7062 - learning_rate: 5.0000e-05
# Epoch 28/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 133ms/step - accuracy: 0.7557 - loss: 1.4304 - val_accuracy: 0.6079 - val_loss: 2.9035 - learning_rate: 5.0000e-05
# Epoch 29/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 133ms/step - accuracy: 0.7539 - loss: 1.3760 - val_accuracy: 0.6237 - val_loss: 2.9462 - learning_rate: 5.0000e-05
# Epoch 30/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 137ms/step - accuracy: 0.7621 - loss: 1.4010 - val_accuracy: 0.6342 - val_loss: 2.8302 - learning_rate: 5.0000e-05
# Epoch 31/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - accuracy: 0.7744 - loss: 1.2587 - val_accuracy: 0.6711 - val_loss: 2.2064 - learning_rate: 5.0000e-05
# Epoch 32/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.7860 - loss: 1.2549 - val_accuracy: 0.6211 - val_loss: 3.2968 - learning_rate: 5.0000e-05
# Epoch 33/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.7872 - loss: 1.1685 - val_accuracy: 0.5868 - val_loss: 3.6593 - learning_rate: 5.0000e-05
# Epoch 34/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.7951 - loss: 1.1133 - val_accuracy: 0.6474 - val_loss: 2.9342 - learning_rate: 5.0000e-05
# Epoch 35/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.8015 - loss: 1.1723 - val_accuracy: 0.6079 - val_loss: 3.1253 - learning_rate: 5.0000e-05
# Epoch 36/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.8059 - loss: 1.1028 - val_accuracy: 0.6500 - val_loss: 2.6122 - learning_rate: 5.0000e-05
# Epoch 37/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 138ms/step - accuracy: 0.8129 - loss: 1.0593 - val_accuracy: 0.6342 - val_loss: 3.1211 - learning_rate: 5.0000e-05
# Epoch 38/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 139ms/step - accuracy: 0.8149 - loss: 1.0186 - val_accuracy: 0.6132 - val_loss: 3.3661 - learning_rate: 5.0000e-05
# Epoch 39/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 139ms/step - accuracy: 0.8170 - loss: 1.0092 - val_accuracy: 0.6000 - val_loss: 3.4809 - learning_rate: 5.0000e-05
# Epoch 40/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - accuracy: 0.8266 - loss: 0.9265 - val_accuracy: 0.6842 - val_loss: 2.4282 - learning_rate: 5.0000e-05
# Epoch 41/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - accuracy: 0.8330 - loss: 0.9284 - val_accuracy: 0.6000 - val_loss: 3.4154 - learning_rate: 5.0000e-05
# Epoch 42/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - accuracy: 0.8508 - loss: 0.8463 - val_accuracy: 0.5816 - val_loss: 3.6481 - learning_rate: 5.0000e-05
# Epoch 43/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - accuracy: 0.8406 - loss: 0.8808 - val_accuracy: 0.6237 - val_loss: 3.4678 - learning_rate: 5.0000e-05
# Epoch 44/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - accuracy: 0.8555 - loss: 0.8133 - val_accuracy: 0.5526 - val_loss: 3.4855 - learning_rate: 5.0000e-05
# Epoch 45/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - accuracy: 0.8538 - loss: 0.8158 - val_accuracy: 0.6500 - val_loss: 3.8012 - learning_rate: 5.0000e-05
# Epoch 46/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - accuracy: 0.8584 - loss: 0.7576 - val_accuracy: 0.5974 - val_loss: 3.2433 - learning_rate: 5.0000e-05
# Epoch 47/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - accuracy: 0.8590 - loss: 0.7765 - val_accuracy: 0.6026 - val_loss: 3.2369 - learning_rate: 5.0000e-05
# Epoch 48/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - accuracy: 0.8622 - loss: 0.7658 - val_accuracy: 0.6395 - val_loss: 3.3806 - learning_rate: 5.0000e-05
# Epoch 49/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - accuracy: 0.8806 - loss: 0.7119 - val_accuracy: 0.6237 - val_loss: 3.6349 - learning_rate: 5.0000e-05
# Epoch 50/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - accuracy: 0.8797 - loss: 0.6730 - val_accuracy: 0.6342 - val_loss: 3.1199 - learning_rate: 5.0000e-05

# %% [markdown]
# ## Evaluación en datos de prueba

# %%
# Evaluar en test dataset
test_loss, test_accuracy = model.evaluate(
    normalized_test_dataset,
)

print(f"\nResultados en Test Dataset:")
print(f"Loss: {test_loss:.4f}")
print(f"Accuracy: {test_accuracy:.4f}")
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6813 - loss: 2.2476
#
# Resultados en Test Dataset:
# Loss: 2.2476
# Accuracy: 0.6813

# %% [markdown]
# ## Visualización de resultados

# %%
# Obtener historial de entrenamiento
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

# Gráficos
plt.figure(figsize=(14, 5))

# Gráfico de Accuracy
plt.subplot(1, 2, 1)
plt.plot(train_acc, label='Train Accuracy', linewidth=2)
plt.plot(val_acc, label='Validation Accuracy', linewidth=2)
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True, alpha=0.3)

# Gráfico de Loss
plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Train Loss', linewidth=2)
plt.plot(val_loss, label='Validation Loss', linewidth=2)
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\nMejor validación Accuracy: {max(val_acc):.4f}")
print(f"Mejor validación Loss: {min(val_loss):.4f}")
# Out:
# Mejor validación Accuracy: 0.6842
# Mejor validación Loss: 2.1773

# %% [markdown]
# ### Matriz de Confusión

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Obtener predicciones y etiquetas reales
y_true = []
y_pred = []

for images, labels in normalized_test_dataset:
    predictions = model.predict(images)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

# Matriz de confusión
cm = confusion_matrix(y_true, y_pred)

# Visualizar
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm, 
    annot=True, 
    fmt='d', 
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 2026-06-06 14:20:53.993319: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Reporte de clasificación
print("\n" + "="*60)
print("                   CLASSIFICATION REPORT")
print("="*60)
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# ============================================================
#                    CLASSIFICATION REPORT
# ============================================================
#                      precision    recall  f1-score   support
#
#           Cardboard       0.63      0.80      0.71        95
#       Food Organics       0.70      0.47      0.56        83
#               Glass       0.94      0.58      0.72        85
#               Metal       0.82      0.71      0.76       158
# Miscellaneous Trash       0.58      0.54      0.56        99
#               Paper       0.63      0.79      0.70       100
#             Plastic       0.63      0.74      0.68       185
#       Textile Trash       0.91      0.33      0.48        64
#          Vegetation       0.64      0.99      0.77        88
#
#            accuracy                           0.68       957
#           macro avg       0.72      0.66      0.66       957
#        weighted avg       0.71      0.68      0.67       957

# %% [markdown]
# ## Guardar modelo final

# %%
model.save("modelo_experimental.keras")
print("Modelo guardado como: modelo_experimental.keras")
print("Mejor modelo guardado como: best_model_experimental.keras")
# Out:
# Modelo guardado como: modelo_experimental.keras
# Mejor modelo guardado como: best_model_experimental.keras
